# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('tree.csv')

lable = LabelEncoder()
df = df.apply(lable.fit_transform)

x = df.drop(columns='play', axis=1)
y = df['play']
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   outlook   100 non-null    int32
#  1   temp      100 non-null    int32
#  2   humidity  100 non-null    int32
#  3   windly    100 non-null    int64
#  4   play      100 non-null    int32
# dtypes: int32(4), int64(1)
# memory usage: 2.5 KB
# None

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, random_state=42, test_size=0.2)

# %%
model = DecisionTreeClassifier()
model.fit(x_train, y_train)

y_pred = model.predict(x_test)

# %%
plt.figure(figsize=(10,10))
plot_tree(
    model
    ,filled=True,          # fill nodes with colors
    rounded=True,
    fontsize=10
    )
# Out:
# [Text(0.4, 0.9285714285714286, 'x[0] <= 0.5\ngini = 0.469\nsamples = 80\nvalue = [30, 50]'),
#  Text(0.3, 0.7857142857142857, 'gini = 0.0\nsamples = 27\nvalue = [0, 27]'),
#  Text(0.35, 0.8571428571428572, 'True  '),
#  Text(0.5, 0.7857142857142857, 'x[2] <= 0.5\ngini = 0.491\nsamples = 53\nvalue = [30, 23]'),
#  Text(0.45, 0.8571428571428572, '  False'),
#  Text(0.3, 0.6428571428571429, 'x[0] <= 1.5\ngini = 0.328\nsamples = 29\nvalue = [23, 6]'),
#  Text(0.2, 0.5, 'x[1] <= 0.5\ngini = 0.497\nsamples = 13\nvalue = [7, 6]'),
#  Text(0.1, 0.35714285714285715, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.3, 0.35714285714285715, 'x[3] <= 0.5\ngini = 0.42\nsamples = 10\nvalue = [7, 3]'),
#  Text(0.2, 0.21428571428571427, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.4, 0.21428571428571427, 'x[1] <= 1.5\ngini = 0.5\nsamples = 6\nvalue = [3, 3]'),
#  Text(0.3, 0.07142857142857142, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.5, 0.07142857142857142, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.4, 0.5, 'gini = 0.0\nsamples = 16\nvalue = [16, 0]'),
#  Text(0.7, 0.6428571428571429, 'x[1] <= 0.5\ngini = 0.413\nsamples = 24\nvalue = [7, 17]'),
#  Text(0.6, 0.5, 'gini = 0.0\nsamples = 7\nvalue = [0, 7]'),
#  Text(0.8, 0.5, 'x[1] <= 1.5\ngini = 0.484\nsamples = 17\nvalue = [7, 10]'),
#  Text(0.7, 0.35714285714285715, 'x[0] <= 1.5\ngini = 0.42\nsamples = 10\nvalue = [7, 3]'),
#  Text(0.6, 0.21428571428571427, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.8, 0.21428571428571427, 'x[3] <= 0.5\ngini = 0.5\nsamples = 6\nvalue = [3, 3]'),
#  Text(0.7, 0.07142857142857142, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.9, 0.07142857142857142, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.9, 0.35714285714285715, 'gini = 0.0\nsamples = 7\nvalue = [0, 7]')]

# %%
print("Accuracy score: ",accuracy_score(y_test, y_pred))
# Out:
# Accuracy score:  1.0
