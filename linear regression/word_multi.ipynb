# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score,mean_absolute_error, mean_absolute_percentage_error,mean_squared_error
from word2number import w2n

# %%
df = pd.read_csv('word.csv')
df['experience'] = df['experience'].apply(w2n.word_to_num)

# %%
x = df[['experience','test_core','interview_score']]
y = df['salary']
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
model = LinearRegression()
model.fit(x_train, y_train)
y_predict = model.predict(x_test)

# %%
print('R2 squre: ', r2_score(y_test, y_predict))
print('MAE: ', mean_absolute_error(y_test, y_predict))
print('MAPE: ', mean_absolute_percentage_error(y_test, y_predict))
print('MSE: ', mean_squared_error(y_test,y_predict))
# Out:
# R2 squre:  0.968891801844536
# MAE:  3255.3927925129346
# MAPE:  0.12634967919886567
# MSE:  32142545.744133115
